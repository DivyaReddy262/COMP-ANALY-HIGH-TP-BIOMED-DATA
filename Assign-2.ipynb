# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress

# Load the data file
file_path = r"C:\Users\kdivy\OneDrive\Desktop\COMP ANA HT DATA\ASSIGN-2\DecayTimecourse (1).txt"
df = pd.read_csv(file_path, sep="\t")
df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Define time points (minutes)
time_points = np.array([0, 5, 10, 15, 20, 30, 40, 50, 60])

# Calculate half-life for each transcript
half_lives = {}
for _, row in df.iterrows():
    gene = row.iloc[0]
    # Reshape expression data into three replicates (3 x 9)
    replicates = row.iloc[1:].values.reshape(3, -1).astype(float)
    gene_hls = []
    for rep in replicates:
        # Filter out invalid values (NaN or non-positive)
        valid = (rep > 0) & ~np.isnan(rep)
        if valid.sum() < 3:
            continue
        # Perform linear regression on log(expression) vs. time
        result = linregress(time_points[valid], np.log(rep[valid]))
        if -result.slope > 0:
            gene_hls.append(np.log(2) / (-result.slope))
    if gene_hls:
        half_lives[gene] = np.mean(gene_hls)

# Save half-life results
hl_df = pd.DataFrame(list(half_lives.items()), columns=["Gene", "Half-life"]).dropna()
hl_df.to_csv("calculated_half_lives.csv", index=False)

# Load half-life data and determine top/bottom 10% by quantile
hl_df = pd.read_csv("calculated_half_lives.csv")
top_threshold = hl_df["Half-life"].quantile(0.9)
bottom_threshold = hl_df["Half-life"].quantile(0.1)

top_genes = hl_df[hl_df["Half-life"] >= top_threshold]
bottom_genes = hl_df[hl_df["Half-life"] <= bottom_threshold]

top_genes.to_csv("top_10_percent_half_lives.csv", index=False)
bottom_genes.to_csv("bottom_10_percent_half_lives.csv", index=False)

print("Top 10% genes:", top_genes["Gene"].tolist())
print("Bottom 10% genes:", bottom_genes["Gene"].tolist())
# Out:
# Top 10% genes: ['YMR261C', 'YLR102C', 'YDR118W', 'YDL008W', 'YOR303W', 'YPR055W', 'YJL031C', 'YDR019C', 'YDR407C', 'YGR238C', 'YPR047W', 'YAL038W', 'YDR052C', 'YGR183C', 'Q0105', 'Q0275', 'Q0130', 'Q0080', 'YOR334W', 'YGL093W', 'Q0140', 'YPR186C', 'YKL058W', 'YLL050C', 'YMR092C', 'YBL078C', 'YHR156C', 'YDR424C', 'YPL174C', 'YMR294W', 'YBL037W', 'YHL019C', 'YOR075W', 'YOR036W', 'YJL041W', 'YER094C', 'YIL075C', 'YPL167C', 'YIL139C', 'YMR061W', 'YBR167C', 'YDR364C', 'YMR268C', 'YBR152W', 'YKL074C', 'YCR018C', 'YDL132W', 'YKL142W', 'YPR166C', 'YFR049W', 'YIL143C', 'YJR052W', 'YNL250W', 'YOL090W', 'YIR017C', 'YPL248C', 'YML039W', 'YMR050C', 'YBL005W-A', 'YKL152C', 'YLR134W', 'YLL024C', 'YMR186W', 'YLR109W', 'YLL039C', 'YPL240C', 'YBR011C', 'YDR077W', 'YPR149W', 'YGR087C', 'YLR259C', 'YMR251W', 'YLR304C', 'YLR087C', 'YHR049W', 'YDR366C', 'YLR216C', 'YBR054W', 'YMR031W-A', 'YKL086W', 'YER057C', 'YMR316C-A', 'YAL066W', 'YDR032C', 'YHR095W', 'YKL035W', 'YFL013W-A', 'YHR008C', 'YBL026W', 'YDR063W', 'YOR027W', 'YOR383C', 'YDR416W', 'YGL026C', 'YDL113C', 'YMR169C', 'YMR280C', 'YBR116C', 'YGL207W', 'YGL215W', 'YOR051C', 'YLR072W', 'YBR017C', 'YAL064W', 'YGR218W', 'YEL030W', 'YOL037C', 'YMR173W-A', 'YPL121C', 'YGR137W', 'YOR345C', 'YFL026W', 'YDR159W', 'YDR503C', 'YNR001C', 'YBR047W', 'YDL118W', 'YDL221W', 'YDR442W', 'YFL012W', 'YNR047W', 'YOL119C', 'YMR068W', 'YNL173C', 'YDL032W', 'YAL037W', 'YML117W-A', 'YOR315W', 'YOR166C', 'YNR057C', 'YEL062W', 'YKL150W', 'YML003W', 'YBL062W', 'YDR275W', 'YMR103C', 'YNL155W', 'YOL106W', 'YEL006W', 'YMR090W', 'YMR010W', 'YLR303W', 'YJR120W', 'YPR007C', 'YMR045C', 'YKL157W', 'YHR136C', 'YPL058C', 'YDL223C', 'YAL058C-A', 'YIL155C', 'YDR274C', 'YPR154W', 'YJL119C', 'YLR363C', 'YAL017W', 'YDR029W', 'YLR423C', 'YML005W', 'YBR085W', 'YPR122W', 'YDR309C', 'YGL088W', 'YKL199C', 'YIR038C', 'YLR162W', 'YCL019W', 'YNL157W', 'YDR072C', 'YPL005W', 'YLR070C', 'YHR214C-B', 'Q0055', 'YNL120C', 'YLR302C', 'YGR136W', 'YER181C', 'YDL035C', 'YFL017W-A', 'YDL027C', 'YPR094W', 'YPR136C', 'YPL245W', 'YDL022W', 'YOR068C', 'YDR445C', 'YPR160W', 'YLR081W', 'YOR305W', 'YKL136W', 'YDR150W', 'YOR251C', 'YAL034W-A', 'YMR299C', 'YOL134C', 'YLR252W', 'YFL016C', 'YDR412W', 'YOR205C', 'YBL101W-B', 'YPR095C', 'YMR290W-A', 'YEL060C', 'YEL071W', 'YGL037C', 'YNL184C', 'YOR173W', 'YNL009W', 'YLR092W', 'YJL022W', 'YBR066C', 'YMR028W', 'YOR379C', 'YNL011C', 'YJL116C', 'YML070W', 'Q0070', 'YNL045W', 'YOL136C', 'YGL193C', 'YLR347C', 'YOR152C', 'YPR098C', 'YNL198C', 'YOL084W', 'YPL152W', 'YKL010C', 'YLL059C', 'YOL020W', 'YIL162W', 'YOL085C', 'YDL039C', 'YOL160W', 'YMR110C', 'YLR270W', 'YDR461W', 'YBL043W', 'YDR265W', 'YBR299W', 'YOL087C', 'YOR376W', 'YMR122C', 'YBR037C', 'YPR077C', 'YGR062C', 'YAL011W', 'YLR053C', 'YOR097C', 'YER066C-A', 'YDR305C', 'YBR099C', 'YDL200C', 'YOR317W', 'YFR035C', 'YDL168W', 'YOR297C', 'YML113W', 'YHL040C', 'YBL064C', 'YDR340W', 'YDL234C', 'YGR233C', 'YDR016C', 'YJR026W', 'YML041C', 'YGL015C', 'YHR100C', 'YDL238C', 'YDR008C', 'YPL170W', 'YKR040C', 'YOL083W', 'YAL067C', 'YHL030W', 'YMR107W', 'YLR178C', 'YBL053W', 'YOR183W', 'YNL008C', 'YPL150W', 'YPL202C', 'YJR114W', 'YGL136C', 'YDR533C', 'YOR255W', 'YDR075W', 'YDL087C', 'YGR164W', 'YDR431W', 'YPL148C', 'YPL095C', 'YML011C', 'YPR150W', 'YJR119C', 'YLR126C', 'YOR072W', 'YOL101C', 'YPL047W', 'YDL176W', 'YDR248C', 'YOR107W', 'YPL258C', 'YNR019W', 'YJL068C', 'YPR045C', 'YLR012C', 'YEL010W', 'YML040W', 'YGR130C', 'YER104W', 'YNR058W', 'YMR278W', 'YLR385C', 'YPL087W', 'YJL107C', 'YBR170C', 'YOR346W', 'YBL098W', 'YKL036C', 'YDL057W', 'YNL159C', 'YOL162W', 'YBL005W', 'YJL049W', 'YBR174C', 'YDR401W', 'YAL002W', 'YJR091C', 'YLR157C', 'YLR258W', 'YBR053C', 'YNL028W', 'YNL187W', 'YLR245C', 'YHL029C', 'YHR199C', 'YNL118C', 'YGR250C', 'YGR199W', 'YKL120W', 'YAL054C', 'YOL015W', 'YIL135C', 'YPR201W', 'YAL015C', 'YPR096C', 'YPR109W', 'YDR374C', 'YJL021C', 'YOR374W', 'YOR298W', 'YGR127W', 'YPR078C', 'YBR076W', 'YML045W', 'YDR204W', 'YDR240C', 'YIR011C', 'YPL281C', 'YCL006C', 'YKR002W', ' ...
# Bottom 10% genes: ['YGL032C', 'YLR127C', 'YOR249C', 'YML102W', 'YBR195C', 'YHR060W', 'YJL164C', 'YHR135C', 'YDR188W', 'YGR108W', 'YPL219W', 'YPL042C', 'YML094W', 'YGL155W', 'YCR034W', 'YMR263W', 'YKL089W', 'YMR080C', 'YGL100W', 'YBR010W', 'YNL030W', 'YDR225W', 'YBL002W', 'YBL003C', 'YBR009C', 'YNL031C', 'YMR035W', 'YDL040C', 'YHR013C', 'YKR008W', 'YLR321C', 'YOR213C', 'YDL017W', 'YJL194W', 'YKL016C', 'YER070W', 'YJL209W', 'YLR382C', 'YOR257W', 'YNL188W', 'YOL069W', 'YMR282C', 'YCR046C', 'YOR358W', 'YGL130W', 'YBL014C', 'YLR141W', 'YPL086C', 'YKR062W', 'YGR005C', 'YIR022W', 'YKL122C', 'YLR288C', 'YPR025C', 'YML104C', 'YKL079W', 'YOR272W', 'YOR058C', 'YMR138W', 'YPR141C', 'YPL254W', 'YDR392W', 'YGL112C', 'YGR261C', 'YOR106W', 'YGL212W', 'YBR091C', 'YLL004W', 'YBR060C', 'YBR202W', 'YBR278W', 'YPR175W', 'YKL113C', 'YOL094C', 'YNL290W', 'YIR008C', 'YBL035C', 'YLR115W', 'YDR280W', 'YHR069C', 'YHR062C', 'YBR257W', 'YLR197W', 'YOR310C', 'YDL014W', 'YDR197W', 'YLR147C', 'YGR074W', 'YML046W', 'YIL061C', 'YHL034C', 'YLL008W', 'YOR048C', 'YMR239C', 'YAR008W', 'YLR375W', 'YLR105C', 'YMR023C', 'YMR260C', 'YER025W', 'YKR026C', 'YPR163C', 'YOR276W', 'YGL049C', 'YLR029C', 'YMR242C', 'YOR063W', 'YPR102C', 'YPL131W', 'YOL039W', 'YBR031W', 'YDR012W', 'YNL178W', 'YKL170W', 'YGR076C', 'YBR251W', 'YNL113W', 'YBR154C', 'YHR143W-A', 'YPL022W', 'YDR369C', 'YNL082W', 'YMR167W', 'YOR363C', 'YIL106W', 'YML099C', 'YDR397C', 'YLR182W', 'YDL056W', 'YBL093C', 'YMR112C', 'YBR193C', 'YDL005C', 'YHR058C', 'YOL135C', 'YPL129W', 'YML015C', 'YCR042C', 'YDR086C', 'YLR378C', 'YOR254C', 'YLR292C', 'YPL094C', 'YPL187W', 'YDL055C', 'YLR198C', 'YMR307W', 'YLR355C', 'YIL053W', 'YER072W', 'YEL026W', 'YGL089C', 'YLR359W', 'YGR037C', 'YDR233C', 'YGR228W', 'YLR300W', 'YDR381W', 'YML106W', 'YJR143C', 'YGR069W', 'YER036C', 'YER055C', 'YDR345C', 'YML126C', 'YNL220W', 'YPL238C', 'YOR232W', 'YJR070C', 'YJR071W', 'YML125C', 'YGR103W', 'YGL148W', 'YDL050C', 'YNL002C', 'YLR372W', 'YER120W', 'YBR187W', 'YBR041W', 'YGL012W', 'YDL182W', 'YLR009W', 'YKL178C', 'YDL131W', 'YNL175C', 'YLR413W', 'YER006W', 'YHL011C', 'YDR276C', 'YNL066W', 'YBR038W', 'YDL070W', 'YDR346C', 'YLR040C', 'YBL028C', 'YML022W', 'YDR496C', 'YLR196W', 'YHR143W', 'YDR365C', 'YBR283C', 'YOR252W', 'YDR227W', 'YNL179C', 'YER031C', 'YOR021C', 'YDR031W', 'YDR083W', 'YLR449W', 'YIL094C', 'YDL144C', 'YMR305C', 'YBL024W', 'YKL077W', 'YNL111C', 'YDR361C', 'YKL099C', 'YJL097W', 'YOR004W', 'YDR091C', 'YCR043C', 'YDR396W', 'YJR069C', 'YNL061W', 'YER002W', 'YGL069C', 'YDL063C', 'YNR067C', 'YEL046C', 'YCL030C', 'YHR170W', 'YJL030W', 'YBR158W', 'YBR244W', 'YDL240W', 'YJR144W', 'YBL068W', 'YDL052C', 'YOR145C', 'YDL148C', 'YEL065W', 'YJL179W', 'YKR013W', 'YJR088C', 'YBL032W', 'YGR251W', 'YJR082C', 'YLR230W', 'YNL181W', 'YIL093C', 'YGR035C', 'YPR143W', 'YIL016W', 'YPL244C', 'YER145C', 'YLR065C', 'YPL043W', 'YLL009C', 'YDL142C', 'YLR017W', 'YNL183C', 'YER156C', 'YKR012C', 'YDL074C', 'YPR009W', 'YNL216W', 'YHR088W', 'YGR029W', 'YML048W', 'YLR285W', 'YIL100W', 'YPL044C', 'YOR294W', 'YKL216W', 'YPL124W', 'YLR319C', 'YOL018C', 'YGR095C', 'YHR187W', 'YDL207W', 'YNL317W', 'YNL147W', 'YOR308C', 'YNL329C', 'YNL332W', 'YKR024C', 'YGL078C', 'YDL212W', 'YBR003W', 'YDL209C', 'YDL213C', 'YDR152W', 'YGL072C', 'YHR149C', 'YLR440C', 'YOR320C', 'YPL108W', 'YNL333W', 'YFR018C', 'YKR035C', 'YOR188W', 'YPR113W', 'YKL004W', 'YOR243C', 'YDR120C', 'YDR413C', 'YNR009W', 'YNL217W', 'YOL124C', 'YOR094W', 'YDR087C', 'YPL266W', 'YNR046W', 'YDR026C', 'YPL163C', 'YOR281C', 'YEL042W', 'YMR185W', 'YBL036C', 'YCR087W', 'YJL200C', 'YKL143W', 'YMR272C', 'YJL208C', 'YDR044W', 'YGR200C', 'YOL149W', 'YGR181W', 'YLR409C', 'YDL121C', 'YOR189W', 'YGL111W', 'YBR155W', 'YPL157W', 'YKL073W', 'YMR221C', 'YLR336C', 'YDL060W', 'YLR380W', 'YPR124W', 'YNL241C', 'YCR090C', 'YML071C', 'YJL064W', 'YLL037W', 'YGR259C', 'YML121W', 'YGL150C', 'YPL227C', 'YOL014W', 'YDL122W', 'YKL165C', 'YBR028C', 'YNL087W', 'YJL004C', 'YNL109W', 'YMR039C', 'YIL161W', 'YBL052C', 'YPL112C', 'YML038C', 'YLL010C ...
